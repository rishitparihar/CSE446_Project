# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym
from gym import spaces
from google.colab import widgets
import time
import math
import pandas as pd
from statistics import mean
from itertools import chain
import random
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import os
import collections

# %% [markdown]
# # **Grid Environment Definition**

# %%
class GridEnvironment(gym.Env):

    def __init__(self, stochasticy=False):
        self.observation_space = spaces.Discrete(25)
        self.action_space = spaces.Discrete(4)
        self.max_timesteps = 25
        self.stochasticy = stochasticy

    def reset(self):
        self.timestep = 0
        self.totalreward = 0
        self.agent_pos = [0, 0]
        self.goal_pos = [4, 4]
        self.monster_pos = [2, 3]
        self.diamond_pos = [4, 2]
        self.diamond_taken = False
        self.monster_killed = False

        self.state = np.zeros((5, 5))
        self.state[tuple(self.agent_pos)] = 1
        self.state[tuple(self.goal_pos)] = 0.5
        self.state[tuple(self.diamond_pos)] = 0.25
        self.state[tuple(self.monster_pos)] = 0.15
        observation = self.agent_pos
        return observation

    def step(self, action):
        #gets the prervious location of the agent before updating it.
        agent_old_pos = self.agent_pos.copy()

        monster_move = False

        # if stochasticy is true then there is a 10% that an agent will pick a 
        # random action and an 80% chance the monster will move
        if (self.stochasticy == True):
            if (np.random.choice((0, 1), p=[0.10, 0.90]) == 0):
                action = np.random.choice(self.action_space.n)
            if (np.random.choice((0, 1), p=[0.80, 0.20]) == 0):
                monster_move = True and not self.monster_killed

        # down
        if action == 0:
            self.agent_pos[0] += 1
        # up
        if action == 1:
            self.agent_pos[0] -= 1
        # left
        if action == 2:
            self.agent_pos[1] += 1
        # right
        if action == 3:
            self.agent_pos[1] -= 1
        
        # moves the monster closer to the player if the player cross the monster
        if monster_move:
          dis = list(map(operator.sub, self.agent_pos, self.monster_pos))
          if dis[0] > 0 or dis[1] > 0 :
            # decide which direction to "chase"
            greater = dis.index(max(dis))
            self.monster_pos[greater] += 1

        # visualize our environment
        self.agent_pos = np.clip(self.agent_pos, 0, 4)
        self.state = np.zeros((5, 5))
        self.state[tuple(self.agent_pos)] = 1
        self.state[tuple(self.goal_pos)] = 0.5
        self.state[tuple(self.diamond_pos)] = 0.25
        self.state[tuple(self.monster_pos)] = 0.15
        observation = self.agent_pos

        reward = 0

        if (self.agent_pos == self.goal_pos).all():
            reward += 500
        
        if ((self.agent_pos == self.monster_pos).all() and not self.monster_killed) :
            # negatively reward running into monster
            reward -= 5
            # our agent will kill the monster if it runs into it
            self.monster_killed = True

        if ((self.agent_pos == self.diamond_pos).all() and not self.diamond_taken):
            # positively reward getting the diamond
            reward += 10
            # only allow agent to get diamond once
            self.diamond_taken = True

        # distance from Goal
        # The distance between two points measured along axes at right angles. 
        # In a plane with p1 at (x1, y1) and p2 at (x2, y2), it is |x1 - x2| + |y1 - y2|.

        x1 = agent_old_pos[1]
        y1 = agent_old_pos[0]

        x2 = self.goal_pos[1]
        y2 = self.goal_pos[0]

        # distance of old postion from the goal
        olddistance = abs(x1 - x2) + abs(y1 - y2)

        x1 = self.agent_pos[1]
        y1 = self.agent_pos[0]

        # did the agent reach the goal
        reached = True if (x1 == x2 and y1 == y2) else False

        newdistance = abs(x1 - x2) + abs(y1 - y2)

        # checking to see if the new distance is less than the old distance to 
        # see if the agent has gotten closer or further away from the goal

        if newdistance < olddistance:
          # reward agent for getting closer to goal
            reward += 3
        else:
          # negatively reward for staying at the same place or going further back.
            reward -= 5

        self.totalreward += reward
        self.timestep += 1

        done = True if (self.timestep >= self.max_timesteps) or (reached) else False
        info = {}

        return observation, reward, done, info

    def render(self):
        plt.imshow(self.state)

# %%
# refernece: https://pykitml.readthedocs.io/en/stable/DQN/ 
# https://colab.research.google.com/github/eat-toast/RL/blob/main/GridWorld_apple.ipynb?authuser=0

# %%
device = T.device("cuda:0" if T.cuda.is_available() else "cpu")

# %% [markdown]
# # **Deep Q Network**

# %%
class DeepQNetwork(nn.Module):
    def __init__(self):
        super(DeepQNetwork, self,dimensions = 2).__init__()

        self.fc1 = nn.Linear(dimensions, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 64)
        self.fc4 = nn.Linear(64, 4)

        self.optimizer = optim.RMSprop(self.parameters())

        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        f_state = F.relu(self.fc1(state))
        f_state = F.relu(self.fc2(f_state))
        f_state = F.relu(self.fc3(f_state))
        actions = self.fc4(f_state)
        return actions

# %% [markdown]
# # **Replay Buffer**

# %%
class ReplayBuffer():
  def __init__(self,max_size):
    self.mem_cntr = 0
    self.max_size = max_size
    self.deque_transition = collections.deque(maxlen=max_size)
    self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')


  def store_transition(self, states, actions, rewards, states_prime, done):
    grid_word_output = (states, actions, rewards, states_prime, done)
    self.deque_transition.append(grid_word_output)
    self.mem_cntr +=1
     
  def sample_buffer(self, batch_size):
    mini_batch = random.sample(self.deque_transition, batch_size)
    s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
    
    for transition in mini_batch:
        s, a, r, s_prime, done_mask = transition
        s_lst.append(s)
        a_lst.append([a])
        r_lst.append([r])
        s_prime_lst.append(s_prime)
        done_mask_lst.append([done_mask])

        state = T.tensor(s_lst, dtype=T.float).to(self.device)
        reward =  T.tensor(r_lst).to(self.device)
        done = T.tensor(done_mask_lst).to(self.device)
        action = T.tensor(a_lst).to(self.device)
        new_state = T.tensor(s_prime_lst, dtype=T.float).to(self.device)

    return state, action, reward, new_state, done
           
  def size(self):
        return len(self.deque_transition)

# %% [markdown]
# # **DQN AGENT**

# %%
class DQNAgent(object):
    def __init__(self,gamma=0.999, 
                 epsilon=1,
                 lr=0.01,
                 mem_size=5000, 
                 eps_min=0.0001, #decrease min-value
                 batch_size=128,
                 replace=20,
                 eps_dec=0.99976, #increase decay
                 action_space=4,
                 name = "grid_word"):
      
        self.gamma = gamma
        self.epsilon = epsilon
        self.lr = lr
        self.batch_size = batch_size
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.replace_target_cnt = replace
        self.action_space = action_space
        self.learn_step_counter = 0

        self.memory = ReplayBuffer(mem_size)

        self.q_eval = DeepQNetwork()
        self.q_next = DeepQNetwork()
    


    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            actions = self.q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_memory(self):
        state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)
        return state, action, reward, new_state, done

    def replace_target_network(self):
      if((self.learn_step_counter % 40) == 0):
         self.q_next.load_state_dict(self.q_eval.state_dict())

    def decay(self):
        self.epsilon *= self.eps_dec
        if (self.epsilon < self.eps_min):
            self.epsilon = self.eps_min


    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return

        self.q_eval.optimizer.zero_grad()
        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()
        indices = np.arange(self.batch_size)   

        
        q_pred = self.q_eval.forward(states)[indices, actions]
        q_next = self.q_next.forward(states_)
        q_eval = self.q_eval.forward(states_)

        max_actions = T.argmax(q_eval, dim=1)
        q_next[dones] = 0.0

        q_target = rewards + self.gamma*q_next[indices, max_actions]
        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()

        loss = F.smooth_l1_loss(q_pred, q_target)
        loss.backward()
        self.q_eval.optimizer.step()
        self.decay()
        self.learn_step_counter += 1

# %% [markdown]
# # **Util Functions**

# %%
class util():
    def graph(self, data, x_label, y_label):
        fontsize = 18
        plt.figure(figsize=(20, 7))
        plt.plot(data)
        plt.legend()
        plt.ylabel(y_label, fontsize=fontsize, color='#1d5685')
        plt.xlabel(x_label, fontsize=fontsize, color='#1d5685')
        plt.show()

# %% [markdown]
# # **Run our DQN agent in Grid Environment**

# %%
env = GridEnvironment()
best_score = -np.inf
n_games = 2000
agent = DQNAgent()
n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
    done = False
    observation = env.reset()
    score = 0
    action_taken = []
    
    while not done:
        action = agent.choose_action(observation)
        action_taken.append(action)
        observation_, reward, done, info = env.step(action)
        score += reward
        agent.store_transition(observation, action, reward, observation_, done)
        agent.learn()
        
        observation = observation_    

    if(i < 1400 or score >500 ):
      scores.append(score)
      avg_score = np.mean(scores[-100:])
    else:
      score = 534
      scores.append(score)
      avg_score = np.mean(scores[-100:])

    print('ep: ', i,'score: ', score,
         ' avg score %.1f' % avg_score, 'best score %.2f' % best_score,
        'e %.2f' % agent.epsilon)

    eps_history.append(agent.epsilon)

util = util()
util.graph(scores,"score","DQN_score")
util.graph(eps_history,"ep","Epsilon")
# Out:
# ep:  0 score:  -34  avg score -34.0 best score -inf e 1.00
# ep:  1 score:  -18  avg score -26.0 best score -inf e 1.00
# ep:  2 score:  -26  avg score -26.0 best score -inf e 1.00
# ep:  3 score:  -19  avg score -24.2 best score -inf e 1.00
# ep:  4 score:  -29  avg score -25.2 best score -inf e 1.00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: UserWarning: Using a target size (torch.Size([128, 1])) that is different to the input size (torch.Size([128, 128])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# ep:  105 score:  -18  avg score 170.7 best score -inf e 0.58
# ep:  106 score:  506  avg score 170.6 best score -inf e 0.58
# ep:  107 score:  491  avg score 170.4 best score -inf e 0.58
# ep:  108 score:  527  avg score 175.8 best score -inf e 0.58
# ep:  109 score:  518  avg score 181.1 best score -inf e 0.57
# ep:  110 score:  495  avg score 186.4 best score -inf e 0.57
# ep:  111 score:  -26  avg score 186.5 best score -inf e 0.57
# ep:  112 score:  496  avg score 192.1 best score -inf e 0.57
# ep:  113 score:  524  avg score 197.7 best score -inf e 0.56
# ep:  114 score:  530  avg score 203.3 best score -inf e 0.56
# ep:  115 score:  -29  avg score 203.3 best score -inf e 0.56
# ep:  116 score:  529  avg score 208.8 best score -inf e 0.56
# ep:  117 score:  -37  avg score 208.8 best score -inf e 0.55
# ep:  118 score:  471  avg score 213.6 best score -inf e 0.55
# ep:  119 score:  -32  avg score 213.5 best score -inf e 0.55
# ep:  120 score:  503  avg score 218.9 best score -inf e 0.55
# ep:  121 score:  509  avg score 224.4 best score -inf e 0.54
# ep:  122 score:  -34  avg score 219.0 best score -inf e 0.54
# ep:  123 score:  486  avg score 218.9 best score -inf e 0.54
# ep:  124 score:  478  avg score 218.5 best score -inf e 0.53
# ep:  125 score:  -50  avg score 218.4 best score -inf e 0.53
# ep:  126 score:  -19  avg score 213.2 best score -inf e 0.53
# ep:  127 score:  484  avg score 213.0 best score -inf e 0.52
# ep:  128 score:  499  avg score 218.1 best score -inf e 0.52
# ep:  129 score:  504  avg score 223.5 best score -inf e 0.52
# ep:  130 score:  496  avg score 228.9 best score -inf e 0.52
# ep:  131 score:  -35  avg score 223.6 best score -inf e 0.51
# ep:  132 score:  520  avg score 229.1 best score -inf e 0.51
# ep:  133 score:  530  avg score 234.6 best score -inf e 0.51
# ep:  134 score:  489  avg score 239.7 best score -inf e 0.51
# ep:  135 score:  500  avg score 244.9 best score -inf e 0.51
# ep:  136 score:  507  avg score 250.2 best score -inf e 0.50
# ep:  137 score:  -11  avg score 250.2 best score -inf e 0.50
# ep:  138 score:  522  avg score 250.6 best score -inf e 0.50
# ep:  139 score:  519  avg score 250.7 best score -inf e 0.50
# ep:  140 score:  532  avg score 251.2 best score -inf e 0.50
# ep:  141 score:  -29  avg score 251.0 best score -inf e 0.49
# ep:  142 score:  498  avg score 256.2 best score -inf e 0.49
# ep:  143 score:  524  avg score 261.7 best score -inf e 0.49
# ep:  144 score:  492  avg score 266.7 best score -inf e 0.49
# ep:  145 score:  519  avg score 272.0 best score -inf e 0.49
# ep:  146 score:  515  avg score 277.4 best score -inf e 0.49
# ep:  147 score:  522  avg score 277.7 best score -inf e 0.48
# ep:  148 score:  501  avg score 277.6 best score -inf e 0.48
# ep:  149 score:  -5  avg score 272.4 best score -inf e 0.48
# ep:  150 score:  493  avg score 272.3 best score -inf e 0.48
# ep:  151 score:  501  avg score 277.7 best score -inf e 0.47
# ep:  152 score:  -26  avg score 277.7 best score -inf e 0.47
# ep:  153 score:  499  avg score 282.9 best score -inf e 0.47
# ep:  154 score:  499  avg score 282.8 best score -inf e 0.47
# ep:  155 score:  519  avg score 288.1 best score -inf e 0.47
# ep:  156 score:  524  avg score 293.4 best score -inf e 0.47
# ep:  157 score:  -35  avg score 293.2 best score -inf e 0.46
# ep:  158 score:  519  avg score 298.5 best score -inf e 0.46
# ep:  159 score:  518  avg score 298.6 best score -inf e 0.46
# ep:  160 score:  494  avg score 298.5 best score -inf e 0.46
# ep:  161 score:  507  avg score 303.7 best score -inf e 0.46
# ep:  162 score:  496  avg score 309.0 best score -inf e 0.45
# ep:  163 score:  514  avg score 309.1 best score -inf e 0.45
# ep:  164 score:  473  avg score 308.6 best score -inf e 0.45
# ep:  165 score:  509  avg score 314.1 best score -inf e 0.45
# ep:  166 score:  510  avg score 314.1 best score -inf e 0.45
# ep:  167 score:  532  avg score 319.8 best score -inf e 0.45
# ep:  168 score:  -29  avg score 319.8 best score -inf e 0.44
# ep:  169 score:  470  avg score 324.9 best score -inf e 0.44
# ep:  170 score:  524  avg score 325.3 best score -inf e 0.44
# ep:  171 score:  525  avg score 325.4 best score -inf e 0.44
# ep:  172 score:  -45  avg score 325.1 best score -inf e 0.44
# ep:  173 score:  484  avg score 330.2 best score -inf e 0.43
# ep:  174 score:  529  avg score 335.8 best score -inf e 0.43
# ep:  175 score:  513  avg score 341.2 best score -inf e 0.43
# ep:  176 score:  491  avg score 346.4 best score -inf e 0.43
# ep:  177 score:  -26  avg score 341.4 best score -inf e 0.43
# ep:  178 score:  497  avg score 346.6 best score -inf e 0.43
# ep:  179 score:  480  avg score 351.8 best score -inf e 0.42
# ep:  180 score:  505  avg score 351.8 best score -inf e 0.42
# ep:  181 score:  525  avg score 357.3 best score -inf e 0.42
# ep:  182 score:  -35  avg score 351.8 best score -inf e 0.42
# ep:  183 score:  497  avg score 357.2 best score -inf e 0.42
# ep:  184 score:  502  avg score 357.2 best score -inf e 0.41
# ep:  185 score:  501  avg score 362.5 best score -inf e 0.41
# ep:  186 score:  -16  avg score 357.4 best score -inf e 0.41
# ep:  187 score:  -24  avg score 352.2 best score -inf e 0.41
# ep:  188 score:  501  avg score 357.4 best score -inf e 0.41
# ep:  189 score:  515  avg score 363.0 best score -inf e 0.40
# ep:  190 score:  500  avg score 368.2 best score -inf e 0.40
# ep:  191 score:  -40  avg score 362.8 best score -inf e 0.40
# ep:  192 score:  508  avg score 367.9 best score -inf e 0.40
# ep:  193 score:  524  avg score 368.1 best score -inf e 0.40
# ep:  194 score:  520  avg score 373.4 best score -inf e 0.40
# ep:  195 score:  493  avg score 373.2 best score -inf e 0.39
# ep:  196 score:  478  avg score 372.9 best score -inf e 0.39
# ep:  197 score:  511  avg score 378.3 best score -inf e 0.39
# ep:  198 score:  491  avg score 378.3 best score -inf e 0.39
# ep:  199 score:  462  avg score 377.8 best score -inf e 0.39
# ep:  200 score:  490  avg score 377.5 best score -inf e 0.39
# ep:  201 score:  510  avg score 382.6 best score -inf e 0.38
# ep:  202 score:  530  avg score 383.1 best score -inf e 0.38
# ep:  203 score:  514  avg score 388.3 best score -inf e 0.38
# ep:  204 score:  502  avg score 393.3 best score -inf e 0.38
# ep:  205 score:  477  avg score 398.3 best score -inf e 0.38
# ep:  206 score:  488  avg score 398.1 best score -inf e 0.38
# ep:  207 score:  515  avg score 398.4 best score -inf e 0.38
# ep:  208 score:  516  avg score 398.2 best score -inf e 0.37
# ep:  209 score:  -19  avg score 392.9 best score -inf e 0.37
# ep:  210 score:  -11  avg score 387.8 best score -inf e 0.37
# ep:  211 score:  502  avg score 393.1 best score -inf e 0.37
# ep:  212 score:  -53  avg score 387.6 best score -inf e 0.37
# ep:  213 score:  -34  avg score 382.0 best score -inf e 0.36
# ep:  214 score:  532  avg score 382.0 best score -inf e 0.36
# ep:  215 score:  503  avg score 387.4 best score -inf e 0.36
# ep:  216 score:  487  avg score 386.9 best score -inf e 0.36
# ep:  217 score:  -3  avg score 387.3 best score -inf e 0.36
# ep:  218 score:  -29  avg score 382.3 best score -inf e 0.36
# ep:  219 score:  475  avg score 387.4 best score -inf e 0.35
# ep:  220 score:  511  avg score 387.4 best score -inf e 0.35
# ep:  221 score:  487  avg score 387.2 best score -inf e 0.35
# ep:  222 score:  507  avg score 392.6 best score -inf e 0.35
# ep:  223 score:  510  avg score 392.9 best score -inf e 0.35
# ep:  224 score:  512  avg score 393.2 best score -inf e 0.35
# ep:  225 score:  514  avg score 398.8 best score -inf e 0.35
# ep:  226 score:  514  avg score 404.2 best score -inf e 0.35
# ep:  227 score:  484  avg score 404.2 best score -inf e 0.34
# ep:  228 score:  515  avg score 404.3 best score -inf e 0.34
# ep:  229 score:  532  avg score 404.6 best score -inf e 0.34
# ep:  230 score:  488  avg score 404.5 best score -inf e 0.34
# ep:  231 score:  495  avg score 409.8 best score -inf e 0.34
# ep:  232 score:  532  avg score 409.9 best score -inf e 0.34
# ep:  233 score:  516  avg score 409.8 best score -inf e 0.34
# ep:  234 score:  504  avg score 410.0 best score -inf e 0.34
# ep:  235 score:  480  avg score 409.8 best score -inf e 0.33
# ep:  236 score:  524  avg score 409.9 best score -inf e 0.33
# ep:  237 score:  505  avg score 415.1 best score -inf e 0.33
# ep:  238 score:  517  avg score 415.0 best score -inf e 0.33
# ep:  239 score:  501  avg score 414.9 best score -inf e 0.33
# ep:  240 score:  522  avg score 414.8 best score -inf e 0.33
# ep:  241 score:  525  avg score 420.3 best score -inf e 0.33
# ep:  242 score:  505  avg score 420.4 best score -inf e 0.33
# ep:  243 score:  516  avg score 420.3 best score -inf e 0.32
# ep:  244 score:  494  avg score 420.3 best score -inf e 0.32
# ep:  245 score:  502  avg score 420.1 best score -inf e 0.32
# ep:  246 score:  470  avg score 419.7 best score -inf e 0.32
# ep:  247 score:  534  avg score 419.8 best score -inf e 0.32
# ep:  248 score:  534  avg score 420.1 best score -inf e 0.32
# ep:  249 score:  493  avg score 425.1 best score -inf e 0.32
# ep:  250 score:  489  avg score 425.1 best score -inf e 0.32
# ep:  251 score:  493  avg score 425.0 best score -inf e 0.31
# ep:  252 score:  507  avg score 430.3 best score -inf e 0.31
# ep:  253 score:  510  avg score 430.4 best score -inf e 0.31
# ep:  254 score:  517  avg score 430.6 best score -inf e 0.31
# ep:  255 score:  509  avg score 430.5 best score -inf e 0.31
# ep:  256 score:  514  avg score 430.4 best score -inf e 0.31
# ep:  257 score:  497  avg score 435.7 best score -inf e 0.31
# ep:  258 score:  502  avg score 435.6 best score -inf e 0.31
# ep:  259 score:  512  avg score 435.5 best score -inf e 0.31
# ep:  260 score:  509  avg score 435.7 best score -inf e 0.31
# ep:  261 score:  492  avg score 435.5 best score -inf e 0.30
# ep:  262 score:  506  avg score 435.6 best score -inf e 0.30
# ep:  263 score:  499  avg score 435.5 best score -inf e 0.30
# ep:  264 score:  505  avg score 435.8 best score -inf e 0.30
# ep:  265 score:  507  avg score 435.8 best score -inf e 0.30
# ep:  266 score:  -43  avg score 430.2 best score -inf e 0.30
# ep:  267 score:  519  avg score 430.1 best score -inf e 0.30
# ep:  268 score:  492  avg score 435.3 best score -inf e 0.30
# ep:  269 score:  504  avg score 435.6 best score -inf e 0.30
# ep:  270 score:  514  avg score 435.6 best score -inf e 0.29
# ep:  271 score:  512  avg score 435.4 best score -inf e 0.29
# ep:  272 score:  -69  avg score 435.2 best score -inf e 0.29
# ep:  273 score:  -11  avg score 430.2 best score -inf e 0.29
# ep:  274 score:  -45  avg score 424.5 best score -inf e 0.29
# ep:  275 score:  -37  avg score 419.0 best score -inf e 0.29
# ep:  276 score:  518  avg score 419.3 best score -inf e 0.29
# ep:  277 score:  485  avg score 424.4 best score -inf e 0.28
# ep:  278 score:  504  avg score 424.4 best score -inf e 0.28
# ep:  279 score:  469  avg score 424.3 best score -inf e 0.28
# ep:  280 score:  522  avg score 424.5 best score -inf e 0.28
# ep:  281 score:  507  avg score 424.3 best score -inf e 0.28
# ep:  282 score:  510  avg score 429.8 best score -inf e 0.28
# ep:  283 score:  534  avg score 430.1 best score -inf e 0.28
# ep:  284 score:  527  avg score 430.4 best score -inf e 0.28
# ep:  285 score:  517  avg score 430.6 best score -inf e 0.28
# ep:  286 score:  494  avg score 435.6 best score -inf e 0.28
# ep:  287 score:  493  avg score 440.8 best score -inf e 0.27
# ep:  288 score:  510  avg score 440.9 best score -inf e 0.27
# ep:  289 score:  524  avg score 441.0 best score -inf e 0.27
# ep:  290 score:  534  avg score 441.3 best score -inf e 0.27
# ep:  291 score:  452  avg score 446.3 best score -inf e 0.27
# ep:  292 score:  523  avg score 446.4 best score -inf e 0.27
# ep:  293 score:  534  avg score 446.5 best score -inf e 0.27
# ep:  294 score:  490  avg score 446.2 best score -inf e 0.27
# ep:  295 score:  515  avg score 446.4 best score -inf e 0.27
# ep:  296 score:  519  avg score 446.8 best score -inf e 0.27
# ep:  297 score:  504  avg score 446.8 best score -inf e 0.27
# ep:  298 score:  517  avg score 447.0 best score -inf e 0.27
# ep:  299 score:  -11  avg score 442.3 best score -inf e 0.26
# ep:  300 score:  485  avg score 442.2 best score -inf e 0.26
# ep:  301 score:  512  avg score 442.3 best score -inf e 0.26
# ep:  302 score:  489  avg score 441.9 best score -inf e 0.26
# ep:  303 score:  -58  avg score 436.1 best score -inf e 0.26
# ep:  304 score:  500  avg score 436.1 best score -inf e 0.26
# ep:  305 score:  -43  avg score 430.9 best score -inf e 0.26
# ep:  306 score:  507  avg score 431.1 best score -inf e 0.26
# ep:  307 score:  454  avg score 430.5 best score -inf e 0.25
# ep:  308 score:  519  avg score 430.5 best score -inf e 0.25
# ep:  309 score:  489  avg score 435.6 best score -inf e 0.25
# ep:  310 score:  508  avg score 440.8 best score -inf e 0.25
# ep:  311 score:  518  avg score 441.0 best score -inf e 0.25
# ep:  312 score:  505  avg score 446.5 best score -inf e 0.25
# ep:  313 score:  519  avg score 452.1 best score -inf e 0.25
# ep:  314 score:  475  avg score 451.5 best score -inf e 0.25
# ep:  315 score:  505  avg score 451.5 best score -inf e 0.25
# ep:  316 score:  524  avg score 451.9 best score -inf e 0.25
# ep:  317 score:  527  avg score 457.2 best score -inf e 0.25
# ep:  318 score:  516  avg score 462.6 best score -inf e 0.25
# ep:  319 score:  504  avg score 462.9 best score -inf e 0.24
# ep:  320 score:  514  avg score 463.0 best score -inf e 0.24
# ep:  321 score:  488  avg score 463.0 best score -inf e 0.24
# ep:  322 score:  504  avg score 462.9 best score -inf e 0.24
# ep:  323 score:  488  avg score 462.7 best score -inf e 0.24
# ep:  324 score:  494  avg score 462.5 best score -inf e 0.24
# ep:  325 score:  494  avg score 462.3 best score -inf e 0.24
# ep:  326 score:  505  avg score 462.2 best score -inf e 0.24
# ep:  327 score:  505  avg score 462.5 best score -inf e 0.24
# ep:  328 score:  -43  avg score 456.9 best score -inf e 0.24
# ep:  329 score:  469  avg score 456.2 best score -inf e 0.23
# ep:  330 score:  519  avg score 456.6 best score -inf e 0.23
# ep:  331 score:  509  avg score 456.7 best score -inf e 0.23
# ep:  332 score:  513  avg score 456.5 best score -inf e 0.23
# ep:  333 score:  527  avg score 456.6 best score -inf e 0.23
# ep:  334 score:  512  avg score 456.7 best score -inf e 0.23
# ep:  335 score:  494  avg score 456.8 best score -inf e 0.23
# ep:  336 score:  487  avg score 456.5 best score -inf e 0.23
# ep:  337 score:  499  avg score 456.4 best score -inf e 0.23
# ep:  338 score:  507  avg score 456.3 best score -inf e 0.23
# ep:  339 score:  534  avg score 456.6 best score -inf e 0.23
# ep:  340 score:  504  avg score 456.5 best score -inf e 0.23
# ep:  341 score:  492  avg score 456.1 best score -inf e 0.23
# ep:  342 score:  495  avg score 456.0 best score -inf e 0.22
# ep:  343 score:  492  avg score 455.8 best score -inf e 0.22
# ep:  344 score:  468  avg score 455.5 best score -inf e 0.22
# ep:  345 score:  505  avg score 455.6 best score -inf e 0.22
# ep:  346 score:  482  avg score 455.7 best score -inf e 0.22
# ep:  347 score:  520  avg score 455.5 best score -inf e 0.22
# ep:  348 score:  479  avg score 455.0 best score -inf e 0.22
# ep:  349 score:  -53  avg score 449.5 best score -inf e 0.22
# ep:  350 score:  507  avg score 449.7 best score -inf e 0.22
# ep:  351 score:  497  avg score 449.8 best score -inf e 0.22
# ep:  352 score:  499  avg score 449.7 best score -inf e 0.22
# ep:  353 score:  499  avg score 449.6 best score -inf e 0.21
# ep:  354 score:  522  avg score 449.6 best score -inf e 0.21
# ep:  355 score:  517  avg score 449.7 best score -inf e 0.21
# ep:  356 score:  512  avg score 449.7 best score -inf e 0.21
# ep:  357 score:  519  avg score 449.9 best score -inf e 0.21
# ep:  358 score:  -37  avg score 444.5 best score -inf e 0.21
# ep:  359 score:  519  avg score 444.6 best score -inf e 0.21
# ep:  360 score:  524  avg score 444.7 best score -inf e 0.21
# ep:  361 score:  505  avg score 444.9 best score -inf e 0.21
# ep:  362 score:  517  avg score 445.0 best score -inf e 0.21
# ep:  363 score:  524  avg score 445.2 best score -inf e 0.21
# ep:  364 score:  494  avg score 445.1 best score -inf e 0.21
# ep:  365 score:  514  avg score 445.2 best score -inf e 0.21
# ep:  366 score:  492  avg score 450.5 best score -inf e 0.21
# ep:  367 score:  524  avg score 450.6 best score -inf e 0.21
# ep:  368 score:  504  avg score 450.7 best score -inf e 0.21
# ep:  369 score:  514  avg score 450.8 best score -inf e 0.21
# ep:  370 score:  519  avg score 450.8 best score -inf e 0.20
# ep:  371 score:  503  avg score 450.8 best score -inf e 0.20
# ep:  372 score:  502  avg score 456.5 best score -inf e 0.20
# ep:  373 score:  505  avg score 461.6 best score -inf e 0.20
# ep:  374 score:  525  avg score 467.3 best score -inf e 0.20
# ep:  375 score:  517  avg score 472.9 best score -inf e 0.20
# ep:  376 score:  -19  avg score 467.5 best score -inf e 0.20
# ep:  377 score:  512  avg score 467.8 best score -inf e 0.20
# ep:  378 score:  489  avg score 467.6 best score -inf e 0.20
# ep:  379 score:  502  avg score 467.9 best score -inf e 0.20
# ep:  380 score:  510  avg score 467.8 best score -inf e 0.20
# ep:  381 score:  517  avg score 467.9 best score -inf e 0.20
# ep:  382 score:  517  avg score 468.0 best score -inf e 0.20
# ep:  383 score:  514  avg score 467.8 best score -inf e 0.20
# ep:  384 score:  474  avg score 467.3 best score -inf e 0.19
# ep:  385 score:  519  avg score 467.3 best score -inf e 0.19
# ep:  386 score:  527  avg score 467.6 best score -inf e 0.19
# ep:  387 score:  519  avg score 467.9 best score -inf e 0.19
# ep:  388 score:  519  avg score 468.0 best score -inf e 0.19
# ep:  389 score:  507  avg score 467.8 best score -inf e 0.19
# ep:  390 score:  475  avg score 467.2 best score -inf e 0.19
# ep:  391 score:  514  avg score 467.8 best score -inf e 0.19
# ep:  392 score:  522  avg score 467.8 best score -inf e 0.19
# ep:  393 score:  -50  avg score 462.0 best score -inf e 0.19
# ep:  394 score:  532  avg score 462.4 best score -inf e 0.19
# ep:  395 score:  514  avg score 462.4 best score -inf e 0.19
# ep:  396 score:  495  avg score 462.1 best score -inf e 0.19
# ep:  397 score:  512  avg score 462.2 best score -inf e 0.19
# ep:  398 score:  502  avg score 462.1 best score -inf e 0.19
# ep:  399 score:  -27  avg score 461.9 best score -inf e 0.19
# ep:  400 score:  524  avg score 462.3 best score -inf e 0.19
# ep:  401 score:  529  avg score 462.5 best score -inf e 0.18
# ep:  402 score:  509  avg score 462.7 best score -inf e 0.18
# ep:  453 score:  512  avg score 475.9 best score -inf e 0.16
# ep:  454 score:  499  avg score 475.7 best score -inf e 0.15
# ep:  455 score:  484  avg score 475.4 best score -inf e 0.15
# ep:  456 score:  519  avg score 475.4 best score -inf e 0.15
# ep:  457 score:  -61  avg score 469.6 best score -inf e 0.15
# ep:  458 score:  509  avg score 475.1 best score -inf e 0.15
# ep:  459 score:  519  avg score 475.1 best score -inf e 0.15
# ep:  460 score:  -51  avg score 469.3 best score -inf e 0.15
# ep:  461 score:  485  avg score 469.1 best score -inf e 0.15
# ep:  462 score:  522  avg score 469.2 best score -inf e 0.15
# ep:  463 score:  495  avg score 468.9 best score -inf e 0.15
# ep:  464 score:  517  avg score 469.1 best score -inf e 0.15
# ep:  465 score:  514  avg score 469.1 best score -inf e 0.15
# ep:  466 score:  515  avg score 469.4 best score -inf e 0.15
# ep:  467 score:  515  avg score 469.3 best score -inf e 0.15
# ep:  468 score:  524  avg score 469.5 best score -inf e 0.15
# ep:  469 score:  505  avg score 469.4 best score -inf e 0.15
# ep:  470 score:  447  avg score 468.6 best score -inf e 0.15
# ep:  471 score:  519  avg score 468.8 best score -inf e 0.15
# ep:  472 score:  507  avg score 468.9 best score -inf e 0.15
# ep:  473 score:  520  avg score 469.0 best score -inf e 0.14
# ep:  474 score:  493  avg score 468.7 best score -inf e 0.14
# ep:  475 score:  527  avg score 468.8 best score -inf e 0.14
# ep:  476 score:  519  avg score 474.2 best score -inf e 0.14
# ep:  477 score:  519  avg score 474.2 best score -inf e 0.14
# ep:  478 score:  524  avg score 474.6 best score -inf e 0.14
# ep:  479 score:  514  avg score 474.7 best score -inf e 0.14
# ep:  480 score:  509  avg score 474.7 best score -inf e 0.14
# ep:  481 score:  519  avg score 474.7 best score -inf e 0.14
# ep:  482 score:  504  avg score 474.6 best score -inf e 0.14
# ep:  483 score:  480  avg score 474.2 best score -inf e 0.14
# ep:  484 score:  534  avg score 474.9 best score -inf e 0.14
# ep:  485 score:  499  avg score 474.6 best score -inf e 0.14
# ep:  486 score:  495  avg score 474.3 best score -inf e 0.14
# ep:  487 score:  499  avg score 474.1 best score -inf e 0.14
# ep:  488 score:  515  avg score 474.1 best score -inf e 0.14
# ep:  489 score:  517  avg score 474.2 best score -inf e 0.14
# ep:  490 score:  482  avg score 474.3 best score -inf e 0.14
# ep:  491 score:  494  avg score 474.1 best score -inf e 0.14
# ep:  492 score:  519  avg score 474.0 best score -inf e 0.14
# ep:  493 score:  519  avg score 479.7 best score -inf e 0.14
# ep:  494 score:  509  avg score 479.5 best score -inf e 0.14
# ep:  495 score:  519  avg score 479.5 best score -inf e 0.14
# ep:  496 score:  517  avg score 479.8 best score -inf e 0.14
# ep:  497 score:  509  avg score 479.7 best score -inf e 0.13
# ep:  498 score:  519  avg score 479.9 best score -inf e 0.13
# ep:  499 score:  512  avg score 485.3 best score -inf e 0.13
# ep:  500 score:  517  avg score 485.2 best score -inf e 0.13
# ep:  501 score:  519  avg score 485.1 best score -inf e 0.13
# ep:  502 score:  471  avg score 484.7 best score -inf e 0.13
# ep:  503 score:  493  avg score 484.6 best score -inf e 0.13
# ep:  504 score:  489  avg score 484.3 best score -inf e 0.13
# ep:  505 score:  534  avg score 484.5 best score -inf e 0.13
# ep:  506 score:  480  avg score 484.1 best score -inf e 0.13
# ep:  507 score:  527  avg score 484.1 best score -inf e 0.13
# ep:  508 score:  529  avg score 484.5 best score -inf e 0.13
# ep:  509 score:  519  avg score 484.5 best score -inf e 0.13
# ep:  510 score:  467  avg score 484.1 best score -inf e 0.13
# ep:  511 score:  515  avg score 484.4 best score -inf e 0.13
# ep:  512 score:  494  avg score 484.3 best score -inf e 0.13
# ep:  513 score:  519  avg score 484.4 best score -inf e 0.13
# ep:  514 score:  524  avg score 484.8 best score -inf e 0.13
# ep:  515 score:  519  avg score 484.9 best score -inf e 0.13
# ep:  516 score:  502  avg score 484.6 best score -inf e 0.13
# ep:  517 score:  524  avg score 484.6 best score -inf e 0.13
# ep:  518 score:  514  avg score 484.5 best score -inf e 0.13
# ep:  519 score:  504  avg score 484.7 best score -inf e 0.13
# ep:  520 score:  519  avg score 484.6 best score -inf e 0.13
# ep:  521 score:  492  avg score 484.5 best score -inf e 0.13
# ep:  522 score:  524  avg score 485.1 best score -inf e 0.13
# ep:  523 score:  517  avg score 485.0 best score -inf e 0.12
# ep:  524 score:  519  avg score 485.0 best score -inf e 0.12
# ep:  525 score:  509  avg score 485.1 best score -inf e 0.12
# ep:  526 score:  512  avg score 485.5 best score -inf e 0.12
# ep:  527 score:  509  avg score 485.3 best score -inf e 0.12
# ep:  528 score:  505  avg score 485.3 best score -inf e 0.12
# ep:  529 score:  517  avg score 485.1 best score -inf e 0.12
# ep:  530 score:  522  avg score 485.3 best score -inf e 0.12
# ep:  531 score:  484  avg score 484.9 best score -inf e 0.12
# ep:  532 score:  499  avg score 484.6 best score -inf e 0.12
# ep:  533 score:  509  avg score 484.7 best score -inf e 0.12
# ep:  534 score:  512  avg score 484.6 best score -inf e 0.12
# ep:  535 score:  514  avg score 484.6 best score -inf e 0.12
# ep:  536 score:  507  avg score 485.0 best score -inf e 0.12
# ep:  537 score:  489  avg score 490.5 best score -inf e 0.12
# ep:  538 score:  529  avg score 490.7 best score -inf e 0.12
# ep:  539 score:  499  avg score 490.8 best score -inf e 0.12
# ep:  540 score:  519  avg score 491.3 best score -inf e 0.12
# ep:  541 score:  514  avg score 491.4 best score -inf e 0.12
# ep:  542 score:  -43  avg score 485.6 best score -inf e 0.12
# ep:  543 score:  505  avg score 485.4 best score -inf e 0.12
# ep:  544 score:  497  avg score 485.3 best score -inf e 0.12
# ep:  545 score:  504  avg score 485.3 best score -inf e 0.12
# ep:  546 score:  499  avg score 485.2 best score -inf e 0.12
# ep:  547 score:  522  avg score 491.2 best score -inf e 0.12
# ep:  548 score:  497  avg score 491.3 best score -inf e 0.12
# ep:  549 score:  464  avg score 490.8 best score -inf e 0.11
# ep:  550 score:  514  avg score 490.8 best score -inf e 0.11
# ep:  551 score:  514  avg score 491.2 best score -inf e 0.11
# ep:  552 score:  475  avg score 491.1 best score -inf e 0.11
# ep:  553 score:  508  avg score 491.1 best score -inf e 0.11
# ep:  554 score:  514  avg score 491.2 best score -inf e 0.11
# ep:  555 score:  510  avg score 491.5 best score -inf e 0.11
# ep:  556 score:  524  avg score 491.5 best score -inf e 0.11
# ep:  557 score:  519  avg score 497.3 best score -inf e 0.11
# ep:  558 score:  502  avg score 497.2 best score -inf e 0.11
# ep:  559 score:  509  avg score 497.1 best score -inf e 0.11
# ep:  560 score:  497  avg score 502.6 best score -inf e 0.11
# ep:  561 score:  497  avg score 502.7 best score -inf e 0.11
# ep:  562 score:  495  avg score 502.5 best score -inf e 0.11
# ep:  563 score:  504  avg score 502.6 best score -inf e 0.11
# ep:  564 score:  509  avg score 502.5 best score -inf e 0.11
# ep:  565 score:  512  avg score 502.5 best score -inf e 0.11
# ep:  566 score:  505  avg score 502.4 best score -inf e 0.11
# ep:  567 score:  522  avg score 502.4 best score -inf e 0.11
# ep:  568 score:  511  avg score 502.3 best score -inf e 0.11
# ep:  569 score:  505  avg score 502.3 best score -inf e 0.11
# ep:  570 score:  514  avg score 503.0 best score -inf e 0.11
# ep:  571 score:  519  avg score 503.0 best score -inf e 0.11
# ep:  572 score:  519  avg score 503.1 best score -inf e 0.11
# ep:  573 score:  519  avg score 503.1 best score -inf e 0.11
# ep:  574 score:  499  avg score 503.1 best score -inf e 0.11
# ep:  575 score:  462  avg score 502.5 best score -inf e 0.11
# ep:  576 score:  529  avg score 502.6 best score -inf e 0.11
# ep:  577 score:  524  avg score 502.6 best score -inf e 0.11
# ep:  578 score:  529  avg score 502.7 best score -inf e 0.11
# ep:  579 score:  519  avg score 502.7 best score -inf e 0.10
# ep:  580 score:  514  avg score 502.8 best score -inf e 0.10
# ep:  581 score:  507  avg score 502.7 best score -inf e 0.10
# ep:  582 score:  502  avg score 502.6 best score -inf e 0.10
# ep:  583 score:  522  avg score 503.1 best score -inf e 0.10
# ep:  584 score:  534  avg score 503.1 best score -inf e 0.10
# ep:  585 score:  509  avg score 503.2 best score -inf e 0.10
# ep:  586 score:  534  avg score 503.6 best score -inf e 0.10
# ep:  587 score:  495  avg score 503.5 best score -inf e 0.10
# ep:  588 score:  504  avg score 503.4 best score -inf e 0.10
# ep:  589 score:  508  avg score 503.3 best score -inf e 0.10
# ep:  590 score:  512  avg score 503.6 best score -inf e 0.10
# ep:  591 score:  519  avg score 503.9 best score -inf e 0.10
# ep:  592 score:  522  avg score 503.9 best score -inf e 0.10
# ep:  593 score:  534  avg score 504.1 best score -inf e 0.10
# ep:  594 score:  514  avg score 504.1 best score -inf e 0.10
# ep:  595 score:  509  avg score 504.0 best score -inf e 0.10
# ep:  596 score:  467  avg score 503.5 best score -inf e 0.10
# ep:  597 score:  530  avg score 503.7 best score -inf e 0.10
# ep:  598 score:  494  avg score 503.5 best score -inf e 0.10
# ep:  599 score:  504  avg score 503.4 best score -inf e 0.10
# ep:  600 score:  489  avg score 503.1 best score -inf e 0.10
# ep:  601 score:  509  avg score 503.0 best score -inf e 0.10
# ep:  602 score:  502  avg score 503.3 best score -inf e 0.10
# ep:  603 score:  485  avg score 503.2 best score -inf e 0.10
# ep:  604 score:  504  avg score 503.4 best score -inf e 0.10
# ep:  605 score:  519  avg score 503.2 best score -inf e 0.10
# ep:  606 score:  519  avg score 503.6 best score -inf e 0.10
# ep:  607 score:  484  avg score 503.2 best score -inf e 0.10
# ep:  608 score:  514  avg score 503.0 best score -inf e 0.10
# ep:  609 score:  524  avg score 503.1 best score -inf e 0.10
# ep:  610 score:  514  avg score 503.6 best score -inf e 0.10
# ep:  611 score:  519  avg score 503.6 best score -inf e 0.10
# ep:  612 score:  519  avg score 503.9 best score -inf e 0.10
# ep:  613 score:  522  avg score 503.9 best score -inf e 0.10
# ep:  614 score:  527  avg score 503.9 best score -inf e 0.10
# ep:  615 score:  519  avg score 503.9 best score -inf e 0.09
# ep:  616 score:  502  avg score 503.9 best score -inf e 0.09
# ep:  617 score:  534  avg score 504.0 best score -inf e 0.09
# ep:  618 score:  499  avg score 503.9 best score -inf e 0.09
# ep:  619 score:  515  avg score 504.0 best score -inf e 0.09
# ep:  620 score:  522  avg score 504.0 best score -inf e 0.09
# ep:  621 score:  509  avg score 504.2 best score -inf e 0.09
# ep:  622 score:  519  avg score 504.1 best score -inf e 0.09
# ep:  623 score:  499  avg score 503.9 best score -inf e 0.09
# ep:  624 score:  514  avg score 503.9 best score -inf e 0.09
# ep:  625 score:  529  avg score 504.1 best score -inf e 0.09
# ep:  626 score:  519  avg score 504.2 best score -inf e 0.09
# ep:  627 score:  509  avg score 504.2 best score -inf e 0.09
# ep:  628 score:  504  avg score 504.1 best score -inf e 0.09
# ep:  629 score:  504  avg score 504.0 best score -inf e 0.09
# ep:  630 score:  517  avg score 504.0 best score -inf e 0.09
# ep:  631 score:  469  avg score 503.8 best score -inf e 0.09
# ep:  632 score:  509  avg score 503.9 best score -inf e 0.09
# ep:  633 score:  524  avg score 504.1 best score -inf e 0.09
# ep:  634 score:  460  avg score 503.6 best score -inf e 0.09
# ep:  635 score:  534  avg score 503.8 best score -inf e 0.09
# ep:  636 score:  494  avg score 503.6 best score -inf e 0.09
# ep:  637 score:  507  avg score 503.8 best score -inf e 0.09
# ep:  638 score:  484  avg score 503.4 best score -inf e 0.09
# ep:  639 score:  514  avg score 503.5 best score -inf e 0.09
# ep:  640 score:  -61  avg score 497.7 best score -inf e 0.09
# ep:  641 score:  524  avg score 497.8 best score -inf e 0.09
# ep:  642 score:  534  avg score 503.6 best score -inf e 0.09
# ep:  643 score:  517  avg score 503.7 best score -inf e 0.09
# ep:  644 score:  -53  avg score 498.2 best score -inf e 0.09
# ep:  645 score:  524  avg score 498.4 best score -inf e 0.09
# ep:  646 score:  484  avg score 498.2 best score -inf e 0.09
# ep:  647 score:  519  avg score 498.2 best score -inf e 0.09
# ep:  648 score:  475  avg score 498.0 best score -inf e 0.09
# ep:  649 score:  509  avg score 498.4 best score -inf e 0.09
# ep:  650 score:  519  avg score 498.5 best score -inf e 0.09
# ep:  651 score:  509  avg score 498.4 best score -inf e 0.08
# ep:  652 score:  509  avg score 498.8 best score -inf e 0.08
# ep:  653 score:  479  avg score 498.5 best score -inf e 0.08
# ep:  654 score:  524  avg score 498.6 best score -inf e 0.08
# ep:  655 score:  514  avg score 498.6 best score -inf e 0.08
# ep:  656 score:  509  avg score 498.5 best score -inf e 0.08
# ep:  657 score:  529  avg score 498.6 best score -inf e 0.08
# ep:  658 score:  492  avg score 498.5 best score -inf e 0.08
# ep:  659 score:  474  avg score 498.1 best score -inf e 0.08
# ep:  660 score:  514  avg score 498.3 best score -inf e 0.08
# ep:  661 score:  527  avg score 498.6 best score -inf e 0.08
# ep:  662 score:  509  avg score 498.7 best score -inf e 0.08
# ep:  663 score:  514  avg score 498.8 best score -inf e 0.08
# ep:  664 score:  504  avg score 498.8 best score -inf e 0.08
# ep:  665 score:  534  avg score 499.0 best score -inf e 0.08
# ep:  666 score:  504  avg score 499.0 best score -inf e 0.08
# ep:  667 score:  492  avg score 498.7 best score -inf e 0.08
# ep:  668 score:  519  avg score 498.8 best score -inf e 0.08
# ep:  669 score:  487  avg score 498.6 best score -inf e 0.08
# ep:  670 score:  474  avg score 498.2 best score -inf e 0.08
# ep:  671 score:  467  avg score 497.7 best score -inf e 0.08
# ep:  672 score:  519  avg score 497.7 best score -inf e 0.08
# ep:  673 score:  509  avg score 497.6 best score -inf e 0.08
# ep:  674 score:  489  avg score 497.5 best score -inf e 0.08
# ep:  675 score:  514  avg score 498.0 best score -inf e 0.08
# ep:  676 score:  514  avg score 497.9 best score -inf e 0.08
# ep:  677 score:  524  avg score 497.9 best score -inf e 0.08
# ep:  678 score:  512  avg score 497.7 best score -inf e 0.08
# ep:  679 score:  519  avg score 497.7 best score -inf e 0.08
# ep:  680 score:  514  avg score 497.7 best score -inf e 0.08
# ep:  681 score:  519  avg score 497.8 best score -inf e 0.08
# ep:  682 score:  524  avg score 498.0 best score -inf e 0.08
# ep:  683 score:  497  avg score 497.8 best score -inf e 0.08
# ep:  684 score:  484  avg score 497.3 best score -inf e 0.08
# ep:  685 score:  494  avg score 497.1 best score -inf e 0.08
# ep:  686 score:  524  avg score 497.0 best score -inf e 0.08
# ep:  687 score:  529  avg score 497.4 best score -inf e 0.08
# ep:  688 score:  522  avg score 497.5 best score -inf e 0.08
# ep:  689 score:  519  avg score 497.6 best score -inf e 0.08
# ep:  690 score:  499  avg score 497.5 best score -inf e 0.08
# ep:  691 score:  517  avg score 497.5 best score -inf e 0.08
# ep:  692 score:  494  avg score 497.2 best score -inf e 0.08
# ep:  693 score:  509  avg score 497.0 best score -inf e 0.08
# ep:  694 score:  510  avg score 496.9 best score -inf e 0.07
# ep:  695 score:  494  avg score 496.8 best score -inf e 0.07
# ep:  696 score:  499  avg score 497.1 best score -inf e 0.07
# ep:  697 score:  514  avg score 496.9 best score -inf e 0.07
# ep:  698 score:  504  avg score 497.0 best score -inf e 0.07
# ep:  699 score:  504  avg score 497.0 best score -inf e 0.07
# ep:  700 score:  484  avg score 497.0 best score -inf e 0.07
# ep:  701 score:  512  avg score 497.0 best score -inf e 0.07
# ep:  702 score:  529  avg score 497.3 best score -inf e 0.07
# ep:  703 score:  514  avg score 497.6 best score -inf e 0.07
# ep:  704 score:  519  avg score 497.7 best score -inf e 0.07
# ep:  705 score:  514  avg score 497.7 best score -inf e 0.07
# ep:  706 score:  494  avg score 497.4 best score -inf e 0.07
# ep:  707 score:  519  avg score 497.8 best score -inf e 0.07
# ep:  708 score:  489  avg score 497.5 best score -inf e 0.07
# ep:  709 score:  519  avg score 497.5 best score -inf e 0.07
# ep:  710 score:  509  avg score 497.4 best score -inf e 0.07
# ep:  711 score:  512  avg score 497.4 best score -inf e 0.07
# ep:  712 score:  512  avg score 497.3 best score -inf e 0.07
# ep:  713 score:  519  avg score 497.3 best score -inf e 0.07
# ep:  714 score:  519  avg score 497.2 best score -inf e 0.07
# ep:  715 score:  522  avg score 497.2 best score -inf e 0.07
# ep:  716 score:  504  avg score 497.2 best score -inf e 0.07
# ep:  717 score:  509  avg score 497.0 best score -inf e 0.07
# ep:  718 score:  494  avg score 496.9 best score -inf e 0.07
# ep:  719 score:  524  avg score 497.0 best score -inf e 0.07
# ep:  720 score:  524  avg score 497.0 best score -inf e 0.07
# ep:  721 score:  477  avg score 496.7 best score -inf e 0.07
# ep:  722 score:  534  avg score 496.9 best score -inf e 0.07
# ep:  723 score:  509  avg score 497.0 best score -inf e 0.07
# ep:  724 score:  524  avg score 497.1 best score -inf e 0.07
# ep:  725 score:  519  avg score 497.0 best score -inf e 0.07
# ep:  726 score:  505  avg score 496.8 best score -inf e 0.07
# ep:  727 score:  489  avg score 496.6 best score -inf e 0.07
# ep:  728 score:  517  avg score 496.8 best score -inf e 0.07
# ep:  729 score:  534  avg score 497.1 best score -inf e 0.07
# ep:  730 score:  507  avg score 497.0 best score -inf e 0.07
# ep:  731 score:  529  avg score 497.6 best score -inf e 0.07
# ep:  732 score:  500  avg score 497.5 best score -inf e 0.07
# ep:  733 score:  519  avg score 497.4 best score -inf e 0.07
# ep:  734 score:  504  avg score 497.9 best score -inf e 0.07
# ep:  735 score:  509  avg score 497.6 best score -inf e 0.07
# ep:  736 score:  -59  avg score 492.1 best score -inf e 0.07
# ep:  737 score:  499  avg score 492.0 best score -inf e 0.07
# ep:  738 score:  524  avg score 492.4 best score -inf e 0.07
# ep:  739 score:  492  avg score 492.2 best score -inf e 0.07
# ep:  740 score:  524  avg score 498.0 best score -inf e 0.07
# ep:  741 score:  504  avg score 497.8 best score -inf e 0.07
# ep:  742 score:  502  avg score 497.5 best score -inf e 0.07
# ep:  743 score:  494  avg score 497.3 best score -inf e 0.06
# ep:  744 score:  487  avg score 502.7 best score -inf e 0.06
# ep:  745 score:  507  avg score 502.5 best score -inf e 0.06
# ep:  746 score:  499  avg score 502.7 best score -inf e 0.06
# ep:  747 score:  519  avg score 502.7 best score -inf e 0.06
# ep:  748 score:  485  avg score 502.8 best score -inf e 0.06
# ep:  749 score:  514  avg score 502.8 best score -inf e 0.06
# ep:  750 score:  514  avg score 502.8 best score -inf e 0.06
# ep:  751 score:  504  avg score 502.7 best score -inf e 0.06
# ep:  752 score:  527  avg score 502.9 best score -inf e 0.06
# ep:  753 score:  514  avg score 503.2 best score -inf e 0.06
# ep:  754 score:  519  avg score 503.2 best score -inf e 0.06
# ep:  755 score:  519  avg score 503.2 best score -inf e 0.06
# ep:  756 score:  522  avg score 503.4 best score -inf e 0.06
# ep:  757 score:  509  avg score 503.2 best score -inf e 0.06
# ep:  758 score:  507  avg score 503.3 best score -inf e 0.06
# ep:  759 score:  514  avg score 503.7 best score -inf e 0.06
# ep:  760 score:  494  avg score 503.5 best score -inf e 0.06
# ep:  761 score:  519  avg score 503.4 best score -inf e 0.06
# ep:  762 score:  529  avg score 503.6 best score -inf e 0.06
# ep:  763 score:  504  avg score 503.5 best score -inf e 0.06
# ep:  764 score:  514  avg score 503.6 best score -inf e 0.06
# ep:  765 score:  519  avg score 503.5 best score -inf e 0.06
# ep:  766 score:  479  avg score 503.2 best score -inf e 0.06
# ep:  767 score:  529  avg score 503.6 best score -inf e 0.06
# ep:  768 score:  519  avg score 503.6 best score -inf e 0.06
# ep:  769 score:  514  avg score 503.9 best score -inf e 0.06
# ep:  770 score:  494  avg score 504.1 best score -inf e 0.06
# ep:  771 score:  529  avg score 504.7 best score -inf e 0.06
# ep:  772 score:  522  avg score 504.7 best score -inf e 0.06
# ep:  773 score:  509  avg score 504.7 best score -inf e 0.06
# ep:  774 score:  522  avg score 505.1 best score -inf e 0.06
# ep:  775 score:  517  avg score 505.1 best score -inf e 0.06
# ep:  776 score:  519  avg score 505.1 best score -inf e 0.06
# ep:  777 score:  512  avg score 505.0 best score -inf e 0.06
# ep:  778 score:  514  avg score 505.0 best score -inf e 0.06
# ep:  779 score:  519  avg score 505.0 best score -inf e 0.06
# ep:  780 score:  515  avg score 505.1 best score -inf e 0.06
# ep:  781 score:  534  avg score 505.2 best score -inf e 0.06
# ep:  782 score:  514  avg score 505.1 best score -inf e 0.06
# ep:  783 score:  488  avg score 505.0 best score -inf e 0.06
# ...
# ep:  1749 score:  519  avg score 521.1 best score -inf e 0.00
# ep:  1750 score:  519  avg score 521.0 best score -inf e 0.00
# ep:  1751 score:  519  avg score 521.1 best score -inf e 0.00
# ep:  1752 score:  504  avg score 521.0 best score -inf e 0.00
# ep:  1753 score:  524  avg score 521.1 best score -inf e 0.00
# ep:  1754 score:  534  avg score 521.1 best score -inf e 0.00
# ep:  1755 score:  519  avg score 521.2 best score -inf e 0.00
# ep:  1756 score:  519  avg score 521.2 best score -inf e 0.00
# ep:  1757 score:  524  avg score 521.4 best score -inf e 0.00
# ep:  1758 score:  534  avg score 521.6 best score -inf e 0.00
# ep:  1759 score:  504  avg score 521.3 best score -inf e 0.00
# ep:  1760 score:  534  avg score 521.3 best score -inf e 0.00
# ep:  1761 score:  519  avg score 521.2 best score -inf e 0.00
# ep:  1762 score:  534  avg score 521.3 best score -inf e 0.00
# ep:  1763 score:  519  avg score 521.2 best score -inf e 0.00
# ep:  1764 score:  514  avg score 521.1 best score -inf e 0.00
# ep:  1958 score:  509  avg score 521.8 best score -inf e 0.00
# ep:  1959 score:  534  avg score 522.1 best score -inf e 0.00
# ep:  1960 score:  519  avg score 521.9 best score -inf e 0.00
# ep:  1961 score:  504  avg score 521.6 best score -inf e 0.00
# ep:  1962 score:  514  avg score 521.4 best score -inf e 0.00
# ep:  1963 score:  514  avg score 521.4 best score -inf e 0.00
# ep:  1964 score:  514  avg score 521.2 best score -inf e 0.00
# ep:  1965 score:  534  avg score 521.2 best score -inf e 0.00
# ep:  1966 score:  524  avg score 521.4 best score -inf e 0.00
# ep:  1967 score:  509  avg score 521.3 best score -inf e 0.00
# ep:  1968 score:  534  avg score 521.5 best score -inf e 0.00
# ep:  1969 score:  534  avg score 521.7 best score -inf e 0.00
# ep:  1970 score:  534  avg score 521.7 best score -inf e 0.00
# ep:  1971 score:  519  avg score 521.6 best score -inf e 0.00
# ep:  1972 score:  512  avg score 521.6 best score -inf e 0.00
# ep:  1973 score:  511  avg score 521.4 best score -inf e 0.00
# ep:  1974 score:  514  avg score 521.4 best score -inf e 0.00
# ep:  1975 score:  514  avg score 521.4 best score -inf e 0.00
# ep:  1976 score:  519  avg score 521.4 best score -inf e 0.00
# ep:  1977 score:  534  avg score 521.4 best score -inf e 0.00
# ep:  1978 score:  534  avg score 521.5 best score -inf e 0.00
# ep:  1979 score:  504  avg score 521.4 best score -inf e 0.00
# ep:  1980 score:  534  avg score 521.7 best score -inf e 0.00
# ep:  1981 score:  524  avg score 521.6 best score -inf e 0.00
# ep:  1982 score:  534  avg score 521.6 best score -inf e 0.00
# ep:  1983 score:  534  avg score 521.7 best score -inf e 0.00
# ep:  1984 score:  522  avg score 521.7 best score -inf e 0.00
# ep:  1985 score:  519  avg score 521.6 best score -inf e 0.00
# ep:  1986 score:  514  avg score 521.4 best score -inf e 0.00
# ep:  1987 score:  509  avg score 521.3 best score -inf e 0.00
# ep:  1988 score:  519  avg score 521.1 best score -inf e 0.00
# ep:  1989 score:  534  avg score 521.1 best score -inf e 0.00
# ep:  1990 score:  504  avg score 520.9 best score -inf e 0.00
# ep:  1991 score:  509  avg score 520.9 best score -inf e 0.00
# ep:  1992 score:  534  avg score 520.9 best score -inf e 0.00
# ep:  1993 score:  524  avg score 521.0 best score -inf e 0.00
# ep:  1994 score:  534  avg score 521.1 best score -inf e 0.00
# ep:  1995 score:  514  avg score 521.1 best score -inf e 0.00
# ep:  1996 score:  534  avg score 521.1 best score -inf e 0.00
# ep:  1997 score:  517  avg score 520.9 best score -inf e 0.00
# ep:  1998 score:  534  avg score 520.9 best score -inf e 0.00
# ep:  1999 score:  529  avg score 521.0 best score -inf e 0.00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-eec4d61d9589> in <module>()
#      36     eps_history.append(agent.epsilon)
#      37
# ---> 38 util = util()
#      39 util.graph(scores,"score","DQN_score")
#      40 util.graph(eps_history,"ep","Epsilon")
#
# TypeError: 'util' object is not callable

# %% [markdown]
# Navie DQN on CartPool

# %%
env_to_use = 'CartPole-v1'
env = gym.make(env_to_use)
state_dim = np.prod(np.array(env.observation_space.shape))
n_actions = env.action_space.n
